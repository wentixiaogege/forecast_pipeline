# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.insert(0, 'src/models/')
sys.path.insert(0, 'src/')
sys.path.insert(0, '../conf')
sys.path.insert(0, '../')
sys.path.insert(0, 'conf/')
from utils import Dataset
from keras.callbacks import Callback
from keras.models import load_model
from keras import backend as K
pd.options.display.max_columns=999 
pd.options.display.max_rows=999

# %%
tr_queries = pd.read_csv('../../../input/kdd2019_regular/phase1/train_queries.csv')
tr_click = pd.read_csv('../../../input/kdd2019_regular/phase1/train_clicks.csv')
tr_plans = pd.read_csv('../../../input/kdd2019_regular/phase1/train_plans.csv')

# %%
len(list(set(tr_queries.sid) -set(tr_plans.sid)))  #--->8946个sid 直接是0  query 但是没有plans的用户
# Out:
# 8946

# %%
tr_click[tr_click.sid.isin(list(set(tr_queries.sid) -set(tr_plans.sid)))]
# Out:
# Empty DataFrame
# Columns: [sid, click_time, click_mode]
# Index: []

# %%
tr_data = tr_queries.merge(tr_click, on='sid', how='left')
tr_data = tr_data.merge(tr_plans, on='sid', how='left')
tr_data = tr_data.drop(['click_time'], axis=1)
tr_data['click_mode'] = tr_data['click_mode'].fillna(0)

# %%
from geopy.distance import geodesic
tr_data['num_o1'] = tr_data['o'].apply(lambda x: float(x.split(',')[0]))
tr_data['num_o2'] = tr_data['o'].apply(lambda x: float(x.split(',')[1]))
tr_data['num_d1'] = tr_data['d'].apply(lambda x: float(x.split(',')[0]))
tr_data['num_d2'] = tr_data['d'].apply(lambda x: float(x.split(',')[1]))
tr_data['num_direct_distance'] = tr_data.apply(lambda x: geodesic((x.num_o2, x.num_o1), (x.num_d2, x.num_d1)).m, axis=1)

# %%
tr_data['num_direct_distance'].min()
# Out:
# 0.0

# %%
tr_data[tr_data.pid.isnull()].shape,tr_data.shape
# Out:
# ((163979, 13), (500000, 13))

# %%
check_zero_mode = tr_data[~tr_data.sid.isin(list(set(tr_queries.sid) -set(tr_plans.sid)))]

# %%
check_zero_mode.click_mode.value_counts()
# Out:
# 2.0     136491
# 7.0      78209
# 1.0      70369
# 9.0      48864
# 5.0      47480
# 0.0      37718
# 3.0      24626
# 10.0     14882
# 4.0      12606
# 6.0      11863
# 11.0      6089
# 8.0       1857
# Name: click_mode, dtype: int64

# %%
# 除去有querys 没有plans  可以看到0的mode还是很多  下面针对分析

# %%
check_zero_mode[(check_zero_mode.click_mode ==0)].pid.value_counts()
# Out:
# 167770.0    302
# 112198.0    233
# 116844.0    146
# 203487.0    124
# 186452.0    113
# 129567.0     98
# 202427.0     93
# 109311.0     91
# 158443.0     87
# 129419.0     67
# 171246.0     66
# 170760.0     65
# 212590.0     65
# 199899.0     62
# 202643.0     59
# 147311.0     57
# 100011.0     52
# 163422.0     49
# 184718.0     46
# 199018.0     46
# 137947.0     45
# 202757.0     44
# 119374.0     43
# 191435.0     42
# 188871.0     41
# 197650.0     41
# 169231.0     39
# 127128.0     38
# 106441.0     36
# 162815.0     36
# 107147.0     36
# 115297.0     35
# 191445.0     35
# 131146.0     34
# 120773.0     33
# 160117.0     33
# 196999.0     33
# 104244.0     32
# 209254.0      9
# 130062.0      9
# 124638.0      9
# 170116.0      9
# 177328.0      9
# 111081.0      9
# 113418.0      9
# 199569.0      9
# 205823.0      9
# 116832.0      9
# 148738.0      9
# 141707.0      9
# 124086.0      9
# 103392.0      9
# 202035.0      9
# 189449.0      9
# 122811.0      9
# 191655.0      9
# 203151.0      9
# 106175.0      9
# 124780.0      9
# 212391.0      9
# 111125.0      9
# 110771.0      9
# 161737.0      8
# 183057.0      8
# 153519.0      8
# 195694.0      8
# 162290.0      8
# 186119.0      8
# 153395.0      8
# 101308.0      8
# 116999.0      8
# 182506.0      8
# 202684.0      8
# 176948.0      8
# 177559.0      8
# 156431.0      8
# 154669.0      8
# 203815.0      8
# 129863.0      8
# 205537.0      8
# 116668.0      8
# 182047.0      8
# 194970.0      8
# 182549.0      8
# 140371.0      8
# 170557.0      8
# 106572.0      8
# 203315.0      8
# 200008.0      8
# 135987.0      8
# 143147.0      8
# 168794.0      7
# 180278.0      7
# 140849.0      7
# 103610.0      7
# 194561.0      7
# 112736.0      7
# 136289.0      7
# 104966.0      7
# 127957.0      7
# 166148.0      7
# 111715.0      7
# 141820.0      7
# 185730.0      7
# 181856.0      7
# 112158.0      7
# 114892.0      7
# 215685.0      7
# 167206.0      7
# 135005.0      7
# 195069.0      7
# 169222.0      7
# 135772.0      7
# 168053.0      7
# 167122.0      7
# 197146.0      7
# 207490.0      7
# 101558.0      7
# 144189.0      7
# 170915.0      7
# 174588.0      7
# 176530.0      7
# 135172.0      7
# 207696.0      7
# 112190.0      7
# 189660.0      7
# 113366.0      7
# 202970.0      7
# 169679.0      7
# 100893.0      7
# 107984.0      7
# 173731.0      7
# 124798.0      7
# 128883.0      7
# 204104.0      7
# 195530.0      7
# 154962.0      7
# 141652.0      6
# 187868.0      6
# 195875.0      6
# 215393.0      6
# 174008.0      6
# 211050.0      6
# 132395.0      6
# 209704.0      6
# 142786.0      6
# 167117.0      6
# 160602.0      6
# 113073.0      6
# 190269.0      6
# 178860.0      6
# 200396.0      6
# 201933.0      6
# 119947.0      6
# 150488.0      6
# 167403.0      6
# 207515.0      6
# 189872.0      6
# 203168.0      6
# 154006.0      6
# 188398.0      6
# 203797.0      6
# 130943.0      6
# 170690.0      6
# 201632.0      6
# 116793.0      6
# 154716.0      6
# 192446.0      6
# 184527.0      6
# 104410.0      6
# 120706.0      6
# 198463.0      6
# 167553.0      6
# 210041.0      6
# 176540.0      6
# 145390.0      6
# 210908.0      6
# 122790.0      6
# 170069.0      6
# 167864.0      6
# 127774.0      6
# 208705.0      6
# 104119.0      6
# 207875.0      6
# 163673.0      6
# 123896.0      6
# 107514.0      6
# 114166.0      6
# 161203.0      6
# 170222.0      6
# 211940.0      6
# 149644.0      6
# 205122.0      6
# 149518.0      6
# 165365.0      6
# 197205.0      6
# 164008.0      6
# 154717.0      6
# 179411.0      6
# 206544.0      6
# 183871.0      6
# 169599.0      6
# 161227.0      6
# 152443.0      6
# 183655.0      6
# 177606.0      6
# 122843.0      6
# 178904.0      6
# 147353.0      6
# 147014.0      6
# 201303.0      6
# 103186.0      6
# 192387.0      6
# 175468.0      6
# 136565.0      6
# 164779.0      6
# 119177.0      6
# 104351.0      6
# 150967.0      6
# 201808.0      6
# 191105.0      6
# 176116.0      6
# 175416.0      6
# 188017.0      6
# 183753.0      6
# 133950.0      6
# 145737.0      6
# 102804.0      6
# 129117.0      6
# 179822.0      6
# 156482.0      6
# 215789.0      6
# 196938.0      6
# 176386.0      6
# 158290.0      6
# 156411.0      6
# 119797.0      6
# 116068.0      5
# 126871.0      5
# 212514.0      5
# 101947.0      5
# 120365.0      5
# 178310.0      5
# 190377.0      5
# 105788.0      5
# 184128.0      5
# 172896.0      5
# 183007.0      5
# 210980.0      5
# 135384.0      5
# 132619.0      5
# 120639.0      5
# 116057.0      5
# 166901.0      5
# 124280.0      5
# 208748.0      5
# 142628.0      5
# 160479.0      5
# 196293.0      5
# 185094.0      5
# 137479.0      5
# 114735.0      5
# 136167.0      5
# 152436.0      5
# 209709.0      5
# 152710.0      5
# 108188.0      5
# 101609.0      5
# 116065.0      5
# 202596.0      5
# 135478.0      5
# 168684.0      5
# 120652.0      5
# 212739.0      5
# 180837.0      5
# 194614.0      5
# 108321.0      5
# 114729.0      5
# 213609.0      5
# 170251.0      5
# 178103.0      5
# 158482.0      5
# 133912.0      5
# 154887.0      5
# 159772.0      5
# 208650.0      5
# 159495.0      5
# 105387.0      5
# 202467.0      5
# 185981.0      5
# 151695.0      5
# 204059.0      5
# 181090.0      5
# 199514.0      5
# 198447.0      5
# 152949.0      5
# 173702.0      5
# 102359.0      5
# 123732.0      5
# 102393.0      5
# 161442.0      5
# 210688.0      5
# 204099.0      5
# 157326.0      5
# 175562.0      5
# 105338.0      5
# 204356.0      5
# 108825.0      5
# 132735.0      5
# 214963.0      5
# 174155.0      5
# 141417.0      5
# 102317.0      5
# 119705.0      5
# 124936.0      5
# 210888.0      5
# 113624.0      5
# 192194.0      5
# 206091.0      5
# 193823.0      5
# 127668.0      5
# 167567.0      5
# 187994.0      5
# 181000.0      5
# 202305.0      5
# 182056.0      5
# 133129.0      5
# 185328.0      5
# 149504.0      5
# 170207.0      5
#            ...
# 206415.0      1
# 141127.0      1
# 140823.0      1
# 111371.0      1
# 206355.0      1
# 140817.0      1
# 157196.0      1
# 140811.0      1
# 173613.0      1
# 127768.0      1
# 177396.0      1
# 173619.0      1
# 107384.0      1
# 157262.0      1
# 200395.0      1
# 173644.0      1
# 173643.0      1
# 103204.0      1
# 120892.0      1
# 196784.0      1
# 173638.0      1
# 211325.0      1
# 206403.0      1
# 104797.0      1
# 173630.0      1
# 173629.0      1
# 140857.0      1
# 140632.0      1
# 157013.0      1
# 198596.0      1
# 127552.0      1
# 156818.0      1
# 184616.0      1
# 173195.0      1
# 119364.0      1
# 215196.0      1
# 102977.0      1
# 205953.0      1
# 140415.0      1
# 116325.0      1
# 205943.0      1
# 140406.0      1
# 189557.0      1
# 205937.0      1
# 170866.0      1
# 163101.0      1
# 15019   607749  112198.0  2018-11-11 08:19:18  116.30,39.81  116.28,39.81
#
#        click_mode            plan_time  \
# 2793          0.0  2018-11-25 18:12:46
# 6358          0.0  2018-10-04 18:49:41
# 10249         0.0  2018-11-08 00:15:57
# 12613         0.0  2018-10-01 14:51:01
# 15019         0.0  2018-11-11 08:19:18
#
#                                                    plans  num_o1  num_o2  \
# 2793   [{"distance": 761, "price": "", "eta": 720, "t...  116.45   39.92
# 6358   [{"distance": 10119, "price": 400, "eta": 2570...  116.30   39.97
# 10249  [{"distance": 5250, "price": 2000, "eta": 822,...  116.32   39.68
# 12613  [{"distance": 2797, "price": 200, "eta": 1637,...  116.56   39.91
# 15019  [{"distance": 2259, "price": 300, "eta": 1073,...  116.30   39.81
#
#        num_d1  num_d2  num_direct_distance
# 2793   116.45   39.92             0.000000
# 6358   116.39   39.99          8001.999431
# 10249  116.27   39.69          4430.618030
# 12613  116.57   39.91           855.058614
# 15019  116.28   39.81          1712.601245

# %%
check_zero_mode[(check_zero_mode.click_mode ==0)&(check_zero_mode.pid ==112198.0)][:5].plans.values
# Out:
# array(['[{"distance": 761, "price": "", "eta": 720, "transport_mode": 5}, {"distance": 739, "price": "", "eta": 220, "transport_mode": 6}, {"distance": 1179, "price": "", "eta": 325, "transport_mode": 3}]',
#        '[{"distance": 10119, "price": 400, "eta": 2570, "transport_mode": 2}, {"distance": 12756, "price": "", "eta": 1670, "transport_mode": 3}, {"distance": 12756, "price": 3500, "eta": 1970, "transport_mode": 4}, {"distance": 12144, "price": 300, "eta": 4423, "transport_mode": 1}]',
#        '[{"distance": 5250, "price": 2000, "eta": 822, "transport_mode": 4}, {"distance": 5250, "price": "", "eta": 642, "transport_mode": 3}, {"distance": 5062, "price": "", "eta": 1531, "transport_mode": 6}, {"distance": 6186, "price": 400, "eta": 2150, "transport_mode": 1}, {"distance": 8410, "price": 500, "eta": 2910, "transport_mode": 7}]',
#        '[{"distance": 2797, "price": 200, "eta": 1637, "transport_mode": 1}, {"distance": 2171, "price": "", "eta": 655, "transport_mode": 6}, {"distance": 5155, "price": "", "eta": 1051, "transport_mode": 3}, {"distance": 5155, "price": 1300, "eta": 1351, "transport_mode": 4}, {"distance": 2087, "price": "", "eta": 1906, "transport_mode": 5}, {"distance": 3733, "price": 300, "eta": 1912, "transport_mode": 2}]',
#        '[{"distance": 2259, "price": 300, "eta": 1073, "transport_mode": 2}, {"distance": 1238, "price": "", "eta": 189, "transport_mode": 3}, {"distance": 1238, "price": 1300, "eta": 309, "transport_mode": 4}, {"distance": 1203, "price": "", "eta": 362, "transport_mode": 6}, {"distance": 1203, "price": "", "eta": 1110, "transport_mode": 5}, {"distance": 1549, "price": 200, "eta": 1538, "transport_mode": 1}]'],
#       dtype=object)

# %%
check_zero_mode[(check_zero_mode.click_mode ==0)].describe()
# Out:
#                 sid            pid  click_mode        num_o1        num_o2  \
# count  3.771800e+04   22078.000000     37718.0  37718.000000  37718.000000
# mean   1.713372e+06  158037.748573         0.0    116.390497     39.941517
# std    1.004697e+06   33788.783970         0.0      0.130199      0.110974
# min    2.000000e+00  100000.000000         0.0    115.500000     39.470000
# 25%    8.161885e+05  128202.000000         0.0    116.310000     39.890000
# 50%    1.763793e+06  160807.000000         0.0    116.390000     39.930000
# 75%    2.592610e+06  186872.500000         0.0    116.450000     39.990000
# max    3.396477e+06  216972.000000         0.0    117.270000     40.950000
#
#              num_d1        num_d2  num_direct_distance
# count  37718.000000  37718.000000         37718.000000
# mean     116.388032     39.946118         12096.248020
# std        0.139047      0.119777         13549.753517
# min      115.440000     39.480000             0.000000
# 25%      116.320000     39.890000          2379.795186
# 50%      116.390000     39.930000          7957.994012
# 75%      116.450000     39.990000         16742.526470
# max      117.370000     40.960000        177943.856426

# %%
check_zero_mode.describe()
# Out:
#                 sid            pid     click_mode        num_o1  \
# count  4.910540e+05  330585.000000  491054.000000  491054.00000
# mean   1.762291e+06  158226.628241       4.060908     116.38782
# std    1.015707e+06   33723.697840       3.090393       0.11601
# min    2.000000e+00  100000.000000       0.000000     115.47000
# 25%    8.106305e+05  127729.000000       2.000000     116.32000
# 50%    1.848142e+06  161617.000000       3.000000     116.38000
# 75%    2.663208e+06  187360.000000       7.000000     116.44000
# max    3.396588e+06  216977.000000      11.000000     117.29000
#
#               num_o2         num_d1         num_d2  num_direct_distance
# count  491054.000000  491054.000000  491054.000000        491054.000000
# mean       39.940439     116.384339      39.944215         12445.781222
# std         0.101780       0.124606       0.109607         12432.745750
# min        39.460000     115.440000      39.460000             0.000000
# 25%        39.890000     116.320000      39.890000          3439.071102
# 50%        39.930000     116.390000      39.920000          9045.657688
# 75%        39.990000     116.440000      39.990000         17231.230133
# max        40.970000     117.370000      40.960000        177943.856426

# %%
# 距离上反应不出来跟mode 0的关系 --》整体和mode 0 没有太多的区分性
# 价格上应该也是类似
# 时间上粗略感觉没啥关系
# 区域上应该也没有
# user 上次点击分析

# %%
check_zero_mode = check_zero_mode.sort_values('req_time')

# %%
fenxi_dt  = '2018-11-01'

# %%
before_zero_mode = check_zero_mode[check_zero_mode.req_time <=fenxi_dt]

after_zero_mode = check_zero_mode[check_zero_mode.req_time >fenxi_dt]

# %%
before_zero_mode_contains = before_zero_mode.groupby('pid').click_mode.apply(lambda x: 1 if 0.0 in x.tolist() else -1).reset_index()

# %%
before_zero_mode_contains.head()
# Out:
#         pid  click_mode
# 0  100000.0           1
# 1  100002.0          -1
# 2  100005.0           1
# 3  100006.0           1
# 4  100007.0          -1

# %%
after_zero_mode[after_zero_mode.pid.isin(before_zero_mode_contains.pid)].click_mode.value_counts()
# Out:
# 2.0     36840
# 7.0     21729
# 1.0     18739
# 5.0     11484
# 9.0      8465
# 0.0      7137
# 3.0      4122
# 10.0     3425
# 4.0      2478
# 6.0      2290
# 11.0     1135
# 8.0       633
# Name: click_mode, dtype: int64

# %%
after_zero_mode[after_zero_mode.pid.isin(before_zero_mode_contains[before_zero_mode_contains.click_mode==1].pid)].click_mode.value_counts()
# Out:
# 2.0     25422
# 7.0     15172
# 1.0     13063
# 5.0      8381
# 9.0      5969
# 0.0      4742
# 3.0      2685
# 10.0     2265
# 4.0      1610
# 6.0      1590
# 11.0      813
# 8.0       437
# Name: click_mode, dtype: int64

# %%
# 下面来看还是跟距离没啥关系

# %%
after_zero_mode[(after_zero_mode.click_mode == 0)&after_zero_mode.pid.isin(before_zero_mode_contains[before_zero_mode_contains.click_mode==1].pid)].num_direct_distance.describe()
# Out:
# count      4742.000000
# mean      11990.851132
# std       13241.165223
# min           0.000000
# 25%        2379.425378
# 50%        7958.114959
# 75%       16970.193468
# max      169535.589913
# Name: num_direct_distance, dtype: float64

# %%
after_zero_mode[(after_zero_mode.click_mode == 0)&after_zero_mode.pid.isin(before_zero_mode_contains[before_zero_mode_contains.click_mode==-1].pid)].num_direct_distance.describe()
# Out:
# count      2395.000000
# mean      11708.063102
# std       12863.879899
# min           0.000000
# 25%        2379.178686
# 50%        7819.194972
# 75%       16389.105162
# max      132438.755404
# Name: num_direct_distance, dtype: float64

# %%
# 之前点击过，确实很有可能再次点击这种方案，可以分析跟时间的关系？

# %%
# user 是否经常使用app；

# %% [markdown]
# # 意外发现

# %%
# 规则如果是一个就是5或者0
check_zero_mode[(check_zero_mode.o ==check_zero_mode.d)].click_mode.value_counts()
# Out:
# 5.0     21662
# 0.0      2552
# 6.0      1216
# 3.0       831
# 1.0       318
# 2.0       112
# 4.0        53
# 7.0        18
# 9.0         6
# 10.0        2
# 8.0         1
# Name: click_mode, dtype: int64

# %%
check_zero_mode[(check_zero_mode.o ==check_zero_mode.d)].head()
# Out:
#          sid       pid             req_time             o             d  \
# 69   1522904  170410.0  2018-11-28 15:39:33  116.31,40.07  116.31,40.07
# 75   1847932  108719.0  2018-11-03 11:16:24  116.34,39.95  116.34,39.95
# 79   2143984       NaN  2018-10-19 20:11:43  116.45,39.93  116.45,39.93
# 96   1975681       NaN  2018-10-11 16:37:17  116.43,39.92  116.43,39.92
# 138   201739       NaN  2018-10-20 06:49:32  116.49,39.91  116.49,39.91
#
#      click_mode            plan_time  \
# 69          5.0  2018-11-28 15:39:33
# 75          5.0  2018-11-03 11:16:24
# 79          5.0  2018-10-19 20:11:43
# 96          5.0  2018-10-11 16:37:17
# 138         0.0  2018-10-20 06:49:32
#
#                                                  plans  num_o1  num_o2  \
# 69   [{"distance": 15, "price": "", "eta": 12, "tra...  116.31   40.07
# 75   [{"distance": 148, "price": "", "eta": 126, "t...  116.34   39.95
# 79   [{"distance": 73, "price": "", "eta": 62, "tra...  116.45   39.93
# 96   [{"distance": 47, "price": "", "eta": 40, "tra...  116.43   39.92
# 138  [{"distance": 452, "price": "", "eta": 386, "t...  116.49   39.91
#
#      num_d1  num_d2  num_direct_distance
# 69   116.31   40.07         6.284908e+06
# 75   116.34   39.95         6.308357e+06
# 79   116.45   39.93         6.320277e+06
# 96   116.43   39.92         6.320517e+06
# 138  116.49   39.91         6.326859e+06

# %%
geodesic((40.07,116.31), (40.07,116.31)).m
# Out:
# 0.0
